# %%
import pandas as pd

# %%
df=pd.read_csv('http://bit.ly/autompg-csv')

# %%
df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70      US
# 1    15.0    8  350.0  165    3693   11.5  70      US
# 2    18.0    8  318.0  150    3436   11.0  70      US
# 3    16.0    8  304.0  150    3433   12.0  70      US
# 4    17.0    8  302.0  140    3449   10.5  70      US
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82      US
# 388  44.0    4   97.0   52    2130   24.6  82  Europe
# 389  32.0    4  135.0   84    2295   11.6  82      US
# 390  28.0    4  120.0   79    2625   18.6  82      US
# 391  31.0    4  119.0   82    2720   19.4  82      US
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# 389              dodge rampage
# 390                ford ranger
# 391                 chevy s-10
#
# [392 rows x 9 columns]

# %%
# %matplotlib inline
df.plot.scatter(x='hp',y='mpg')
# Out:
# <AxesSubplot:xlabel='hp', ylabel='mpg'>

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'displ', 'hp', 'weight', 'accel', 'yr', 'origin', 'name'], dtype='object')

# %%
df['mpg*cyl']==df['mpg']*df['cyl']
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 387    True
# 388    True
# 389    True
# 390    True
# 391    True
# Length: 392, dtype: bool

# %%
df.T
# Out:
#                                0                  1                   2    \
# mpg                           18.0               15.0                18.0
# cyl                              8                  8                   8
# displ                        307.0              350.0               318.0
# hp                             130                165                 150
# weight                        3504               3693                3436
# accel                         12.0               11.5                11.0
# yr                              70                 70                  70
# origin                          US                 US                  US
# name     chevrolet chevelle malibu  buick skylark 320  plymouth satellite
# mpg*cyl                      144.0              120.0               144.0
#
#                    3            4                 5                 6    \
# mpg               16.0         17.0              15.0              14.0
# cyl                  8            8                 8                 8
# displ            304.0        302.0             429.0             454.0
# hp                 150          140               198               220
# weight            3433         3449              4341              4354
# accel             12.0         10.5              10.0               9.0
# yr                  70           70                70                70
# origin              US           US                US                US
# name     amc rebel sst  ford torino  ford galaxie 500  chevrolet impala
# mpg*cyl          128.0        136.0             120.0             112.0
#
#                        7                 8                   9    ...  \
# mpg                   14.0              14.0                15.0  ...
# cyl                      8                 8                   8  ...
# displ                440.0             455.0               390.0  ...
# hp                     215               225                 190  ...
# weight                4312              4425                3850  ...
# accel                  8.5              10.0                 8.5  ...
# yr                      70                70                  70  ...
# origin                  US                US                  US  ...
# name     plymouth fury iii  pontiac catalina  amc ambassador dpl  ...
# mpg*cyl              112.0             112.0               120.0  ...
#
#                                 382             383               384  \
# mpg                            26.0            22.0              32.0
# cyl                               4               6                 4
# displ                         156.0           232.0             144.0
# hp                               92             112                96
# weight                         2585            2835              2665
# accel                          14.5            14.7              13.9
# yr                               82              82                82
# origin                           US              US              Asia
# name     chrysler lebaron medallion  ford granada l  toyota celica gt
# mpg*cyl                       104.0           132.0             128.0
#
#                        385               386              387        388  \
# mpg                   36.0              27.0             27.0       44.0
# cyl                      4                 4                4          4
# displ                135.0             151.0            140.0       97.0
# hp                      84                90               86         52
# weight                2370              2950             2790       2130
# accel                 13.0              17.3             15.6       24.6
# yr                      82                82               82         82
# origin                  US                US               US     Europe
# name     dodge charger 2.2  chevrolet camaro  ford mustang gl  vw pickup
# mpg*cyl              144.0             108.0            108.0      176.0
#
#                    389          390         391
# mpg               32.0         28.0        31.0
# cyl                  4            4           4
# displ            135.0        120.0       119.0
# hp                  84           79          82
# weight            2295         2625        2720
# accel             11.6         18.6        19.4
# yr                  82           82          82
# origin              US           US          US
# name     dodge rampage  ford ranger  chevy s-10
# mpg*cyl          128.0        112.0       124.0
#
# [10 rows x 392 columns]

# %% [markdown]
# ## Factorial

# %%
# %time
def fa(n):
    p=1
    while n>1:
        p *=n
        n -=1
    return p
# %time
fa(100)
# Out:
# Wall time: 0 ns
# Wall time: 0 ns
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
import tensorflow as tf
import tensorflow.keras as kr

from IPython.core.display import display, HTML

X, Y = make_circles(n_samples=500, factor=0.5, noise=0.05)

lr = 0.01           # learning rate
nn = [2, 16, 8, 1]  # número de neuronas por capa.


# Creamos el objeto que contendrá a nuestra red neuronal, como
# secuencia de capas.
model = kr.Sequential()

# Añadimos la capa 1
l1 = model.add(kr.layers.Dense(nn[1], activation='relu'))

# Añadimos la capa 2
l2 = model.add(kr.layers.Dense(nn[2], activation='relu'))

# Añadimos la capa 3
l3 = model.add(kr.layers.Dense(nn[3], activation='sigmoid'))

# Compilamos el modelo, definiendo la función de coste y el optimizador.
model.compile(loss='mse', optimizer=kr.optimizers.SGD(lr=0.05), metrics=['acc'])

# Y entrenamos al modelo. Los callbacks 
model.fit(X, Y, epochs=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\OSVALD~2\AppData\Local\Temp/ipykernel_12360/3471212195.py in <module>
#       4 from IPython.core.display import display, HTML
#       5
# ----> 6 X, Y = make_circles(n_samples=500, factor=0.5, noise=0.05)
#       7
#       8 lr = 0.01           # learning rate
#
# NameError: name 'make_circles' is not defined
